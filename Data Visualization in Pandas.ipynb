# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\User\OneDrive\DATA ANALIST PROYECTS\Pandas Projects\Ice Cream Ratings.csv")
df = df.set_index('Date')
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
df.plot(kind = 'line', title = 'ICE CREAM RATING',xlabel ='DATE',ylabel = 'ESCORES')
# Out:
# <Axes: title={'center': 'ICE CREAM RATING'}, xlabel='DATE', ylabel='ESCORES'>

# %%
df.plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.barh(stacked = True)
# Out:
# <Axes: ylabel='Date'>

# %%
#Grafico que Muestra a traves de los puntos...

# %%
df.plot.scatter( x ='Texture Rating', y = 'Overall Rating',c = 'Black', s = 250)
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
#taking a look to the histogram it shows the distribution of the valew

# %%
df.plot.hist(bins = 80)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.plot.area()
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.pie(y = 'Flavor Rating', figsize = (10,5))
# Out:
# <Axes: ylabel='Flavor Rating'>
